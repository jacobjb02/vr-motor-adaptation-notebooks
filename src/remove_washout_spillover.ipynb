# %%
import numpy as np
import pandas as pd





def remove_spillover(data,
                     group_cols
                    ):

    # need to create a df that shows:


    data_grouped = data.groupby(group_cols).count[['block','target_x_label','water_speed_binary']]


    return data_grouped

    # go through each block with
        # target_x_label
        # water_speed_binary
        # ntrials

# %%
remove_spillover

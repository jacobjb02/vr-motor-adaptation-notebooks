# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols, mixedlm

import time
from datetime import date

# updated src file changes are loaded
# %load_ext autoreload
# %autoreload 2

# provides interactive "R studio-like" view of dataframes
from itables import init_notebook_mode, show
init_notebook_mode(all_interactive=True)

# ensures function files are visible: can use 'src.loading' for example
sys.path.append(os.path.abspath(".."))
# Out:
# <script type="module">
#     const { set_or_remove_dark_class } = await import(window._itables_2_6_2);
#     set_or_remove_dark_class();
# </script>
# <script>
# function injectCSS(base64CSS) {
#     const cssText = atob(base64CSS);
#     const style = document.createElement('style');
#     style.textContent = cssText;
#     document.head.appendChild(style);
# }
#
# async function injectModule(base64JS) {
#     const jsText = atob(base64JS);
#     const blob = new Blob([jsText], { type: 'application/javascript' });
#     const url = URL.createObjectURL(blob);
#     const module = await import(url);
#     URL.revokeObjectURL(url);
#     return module;
# }
#
# if (!window._itables_2_6_2) {
#     injectCSS("...");
#     window._itables_2_6_2 = injectModule("...");
#     window._itables_2_6_2.then(() => {
#         window.dispatchEvent(new Event("itables-2.6.2-ready"));
#     });
# }
# </script>
#
# <div style="vertical-align:middle; text-align:left">
# <noscript>
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# This is the <code>init_notebook_mode</code> cell from ITables v2.6.2<br>
# (you should not see this message - is your notebook <it>trusted</it>?)
# </noscript>
# </div>

# %%
### TARGET PAIR DESIGN

# %%
### OPEN PCA CSV

# %%
df = pd.read_csv(r'C:\Users\jacob\water_current_MA\data\dual_generalization\PCA_error_projectile_experiment _S1-projectile_experiment_S2-projectile_experiment_S1_3.0M-projectile_experiment 1_S2_3.0M-projectile_experiment 1_speed_neg3_0_neg2_0_0_0.csv')
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39068 entries, 0 to 39067
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   experiment                39068 non-null  object
#  1   ppid_full                 39068 non-null  object
#  2   speed_label               39068 non-null  float64
#  3   target_x_label            39068 non-null  object
#  4   target_position_x_cm      39068 non-null  float64
#  5   target_position_z_cm      39068 non-null  float64
#  6   trial_num                 39068 non-null  int64
#  7   phase                     39068 non-null  object
#  8   phase_target_trial_num    39068 non-null  int64
#  9   trial_num_target          39068 non-null  int64
#  10  global_cycle_num          39068 non-null  int64
#  11  cycle_target_num          39068 non-null  int64
#  12  cycle_TargetxPhase_num    39068 non-null  int64
#  13  launch_deviation          39068 non-null  float64
#  14  launch_Speed              39068 non-null  float64
#  15  ball_dist_to_center_cm    39068 non-null  float64
#  16  signed_euclidean_cm       39068 non-null  float64
#  17  lateral_error_x_cm        39068 non-null  float64
#  18  depth_error_z_cm          39068 non-null  float64
#  19  target_hit                39068 non-null  bool
#  20  water_speed_binary        39068 non-null  int64
#  21  water_speed_m_s           39068 non-null  float64
#  22  sign_label                39068 non-null  object
#  23  set_order                 39068 non-null  object
#  24  min_pos_from_target_x_cm  39068 non-null  float64
#  25  min_pos_from_target_z_cm  39068 non-null  float64
#  26  target_angle_90           39068 non-null  float64
#  27  pc_vector_1_angle         39068 non-null  float64
#  28  pc_vector_1_pca_center_x  39068 non-null  float64
#  29  pc_vector_1_pca_center_z  39068 non-null  float64
#  30  pc_vector_1_c_X           39068 non-null  float64
#  31  pc_vector_1_c_Z           39068 non-null  float64
#  32  pc_rad                    39068 non-null  float64
#  33  centered_x                39068 non-null  float64
#  34  centered_z                39068 non-null  float64
#  35  unrotated_x               39068 non-null  float64
#  36  unrotated_z               39068 non-null  float64
#  37  tgt_centered_x            39068 non-null  float64
#  38  tgt_centered_z            39068 non-null  float64
#  39  tgt_unrotated_x           39068 non-null  float64
#  40  tgt_unrotated_z           39068 non-null  float64
#  41  PCA_error_X_cm            39068 non-null  float64
#  42  PCA_error_Z_cm            39068 non-null  float64
#  43  PCA_error_X_cm_mean       39068 non-null  float64
#  44  PCA_error_X_cm_median     39068 non-null  float64
#  45  PCA_error_X_cm_mean_bc    39068 non-null  float64
#  46  PCA_error_X_cm_median_bc  39068 non-null  float64
# dtypes: bool(1), float64(33), int64(7), object(6)
# memory usage: 13.7+ MB
# None
#                             experiment  ppid_full  speed_label target_x_label  \
# 0               projectile_experiment   p000_neg2         -2.0            R60
# 1               projectile_experiment   p000_neg2         -2.0            L30
# 2               projectile_experiment   p000_neg2         -2.0            R30
# 3               projectile_experiment   p000_neg2         -2.0            L60
# 4               projectile_experiment   p000_neg2         -2.0            R60
# ...                                ...        ...          ...            ...
# 39063  S2_3.0M-projectile_experiment 1  p050_neg3         -3.0            R30
# 39064  S2_3.0M-projectile_experiment 1  p050_neg3         -3.0            R30
# 39065  S2_3.0M-projectile_experiment 1  p050_neg3         -3.0            L60
# 39066  S2_3.0M-projectile_experiment 1  p050_neg3         -3.0            R30
# 39067  S2_3.0M-projectile_experiment 1  p050_neg3         -3.0            L60
#
#        target_position_x_cm  target_position_z_cm  trial_num      phase  \
# 0                      60.0                 140.0         21   baseline
# 1                     -30.0                 140.0         22   baseline
# 2                      30.0                 140.0         23   baseline
# 3                     -60.0                 140.0         24   baseline
# 4                      60.0                 140.0         25   baseline
# ...                     ...                   ...        ...        ...
# 39063                  30.0                 140.0        492  washout_2
# 39064                  30.0                 140.0        493  washout_2
# 39065                 -60.0                 140.0        494  washout_2
# 39066                  30.0                 140.0        495  washout_2
# 39067                 -60.0                 140.0        496  washout_2
#
#        phase_target_trial_num  trial_num_target  ...  tgt_centered_x  \
# 0                           1                 6  ...       -2.979414
# 1                           1                 6  ...       -5.684806
# 2                           1                 6  ...       -6.701501
# 3                           1                 6  ...       -8.935278
# 4                           2                 7  ...       -2.979414
# ...                       ...               ...  ...             ...
# 39063                      34               122  ...       -5.212916
# 39064                      35               123  ...       -5.212916
# 39065                      35               123  ...       -5.964219
# 39066                      36               124  ...       -5.212916
# 39067                      36               124  ...       -5.964219
#
#        tgt_centered_z  tgt_unrotated_x  tgt_unrotated_z  PCA_error_X_cm  \
# 0            7.283544        -6.071253         5.006676       -1.750010
# 1            4.519692        -5.853857         4.298488       15.114543
# 2            7.220195        -9.044805         3.902927        6.284811
# 3            5.019826        -9.226709         4.461580        3.306500
# 4            7.283544        -6.071253         5.006676        6.542700
# ...               ...              ...              ...             ...
# 39063        6.560305        -7.193396         4.297341      -12.843922
# 39064        6.560305        -7.193396         4.297341        5.291093
# 39065        4.917723        -5.492578         5.439439        7.236622
# 39066        6.560305        -7.193396         4.297341       -7.061737
# 39067        4.917723        -5.492578         5.439439       40.058578
#
#        PCA_error_Z_cm  PCA_error_X_cm_mean  PCA_error_X_cm_median  \
# 0           -8.243838             4.548843               4.258677
# 1            0.823505             8.456296              15.114543
# 2           -5.800593            12.955783              10.327003
# 3           -7.583644             8.811999               4.939291
# 4           -4.539085             4.548843               4.258677
# ...               ...                  ...                    ...
# 39063       -2.878040             3.369440              -6.713816
# 39064       -3.567783             3.369440              -6.713816
# 39065       -3.979986             1.594520              -9.421024
# 39066       -3.245434             3.369440              -6.713816
# 39067       -1.997163             1.594520              -9.421024
#
#        PCA_error_X_cm_mean_bc  PCA_error_X_cm_median_bc
# 0                   -6.298853                 -6.008686
# 1                    6.658247                  0.000000
# 2                   -6.670971                 -4.042191
# 3                   -5.505500                 -1.632791
# 4                    1.993857                  2.284024
# ...                       ...                       ...
# 39063              -16.213361                 -6.130105
# 39064                1.921653                 12.004909
# 39065                5.642103                 16.657647
# 39066              -10.431177                 -0.347921
# 39067               38.464058                 49.479602
#
# [39068 rows x 47 columns]

# %%
from src.plotting import plot_all_trials


plot_all_trials(df, 
                    col_col='set_order',
                     row_col='speed_label',
                    target_col='target_x_label',
                     cond_col=0,
                     ppid_col='ppid_full',
                     y_col = 'PCA_error_X_cm_mean_bc', 
                     x_col='trial_num_target',
                     context='poster', 
                     font_scale=3,
                     marker_size=0,
                     estimator='mean',
                     y_lim=(-80,80),
                     show_zero_line=True
                    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 4
#       1 from src.plotting import plot_all_trials
# ----> 4 plot_all_trials(df,
#       5                     col_col='set_order',
#       6                      row_col='speed_label',
#       7                     target_col='target_x_label',
#       8                      cond_col=0,
#       9                      ppid_col='ppid_full',
#      10                      y_col = 'PCA_error_X_cm_mean_bc',
#      11                      x_col='trial_num_target',
#      12                      context='poster',
#      13                      font_scale=3,
#      14                      marker_size=0,
#      15                      estimator='mean',
#      16                      y_lim=(-80,80),
#      17                      show_zero_line=True
#      18                     )
#
# File ~\water_current_MA\src\plotting.py:308, in plot_all_trials(data, cond_col, ppid_col, row_col, col_col, target_col, transition_col, show_sd_line, show_zero_line, y_col, y_lim, x_col, estimator, context, marker_size, font_scale, save_path, dpi)
#     304             break
#     306 if handles:
#     307     g.fig.legend(handles, legend_labels,
# --> 308                  title=cond_col.replace("_"," ").title(),
#     309                  loc="center left",
#     310                  bbox_to_anchor=(0.88, 0.5),
#     311                  frameon=True)
#     313 g.fig.subplots_adjust(right=0.82, bottom=0.2, left=0.1, wspace=0.1)
#     315 if save_path:
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
### GENERALIZATION

# %%
# make training df with only early trial means
training_gen = early_late_4_means[early_late_4_means['trial_set'] == 'early']

training_gen.head(8)
# Out:
#     ppid_full trial_set target_x_label  set_order       phase  speed_label  \
# 0      1_neg3     early         neg0.3          1  training_2         -3.0
# 1      1_neg3     early         neg0.6          1  training_1         -3.0
# 2      1_neg3     early           p0.3          1  training_1         -3.0
# 3      1_neg3     early           p0.6          1  training_2         -3.0
# 8   p000_neg2     early         neg0.3          1  training_2         -2.0
# 9   p000_neg2     early         neg0.6          1  training_1         -2.0
# 10  p000_neg2     early           p0.3          1  training_1         -2.0
# 11  p000_neg2     early           p0.6          1  training_2         -2.0
#
#     mean_error    var_error  mean_launch_dev  mean_launch_speed  n
# 0    15.890163   964.077437       -62.294877           3.515110  4
# 1   -13.013906  1527.578194       -53.088613           2.612925  4
# 2   -59.351670   444.973963       -46.479580           2.836479  4
# 3   -39.947028    38.613563       -30.604627           3.535021  4
# 8   -25.619568   320.832666        -2.873657           4.125902  4
# 9   -48.531564   913.353181       -15.220048           1.584824  4
# 10  -68.924435   320.024647        -7.490580           1.775173  4
# 11  -29.001646   278.351148         2.868968           4.070343  4

# %%
from src.plotting import plot_generalization

plot_generalization(training_gen, y_col='mean_error', context='poster', font_scale=3, cond_col='speed_label', show_zero_line=True)
# Out:
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
from src.plotting import plot_generalization

plot_generalization(training_gen, 
                    y_col='mean_launch_dev', 
                    context='poster', 
                    font_scale=3, 
                    cond_col='speed_label', 
                    show_zero_line=True)
# Out:
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
from src.plotting import plot_generalization

plot_generalization(training_gen, 
                    y_col='mean_launch_speed', 
                    context='poster', 
                    font_scale=3, 
                    cond_col='speed_label', 
                    show_zero_line=True)
# Out:
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\jacob\anaconda3\envs\water_current_project\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#4c72b0'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
### SPATIAL GENERALIZATION DESIGN

# %%
from src.loading import load_data


df_spatial_2 = load_data("../data/target_trial_spatial_generalization.parquet")
# # drop every row from participant p007
df_spatial_2 = df_spatial_2[df_spatial_2['ppid'] != 'p007'].copy()

# %%
df_spatial_2
# Out:
#                           experiment  ppid  session_num  trial_num  block_num  \
# 0     TD_2.0M_spatial_generalization  p001            1          1          1
# 1     TD_2.0M_spatial_generalization  p001            1          2          1
# 2     TD_2.0M_spatial_generalization  p001            1          3          1
# 3     TD_2.0M_spatial_generalization  p001            1          4          1
# 4     TD_2.0M_spatial_generalization  p001            1          5          2
# ...                              ...   ...          ...        ...        ...
# 7324  TD_2.0M_spatial_generalization  p023            1        381         84
# 7325  TD_2.0M_spatial_generalization  p023            1        382         85
# 7326  TD_2.0M_spatial_generalization  p023            1        383         85
# 7327  TD_2.0M_spatial_generalization  p023            1        384         85
# 7328  TD_2.0M_spatial_generalization  p023            1        385         85
#
#       trial_num_in_block  start_time    end_time hand target_hit  ...  \
# 0                      1    10.77260    13.71950    r      False  ...
# 1                      2    13.71950    17.25783    r      False  ...
# 2                      3    17.25783    20.09750    r      False  ...
# 3                      4    20.09750    23.43839    r      False  ...
# 4                      1    23.43839    26.04162    r       True  ...
# ...                  ...         ...         ...  ...        ...  ...
# 7324                   4  1531.52500  1534.39300    r       True  ...
# 7325                   1  1534.39300  1537.17700    r      False  ...
# 7326                   2  1537.17700  1540.10000    r      False  ...
# 7327                   3  1540.10000  1542.95400    r       True  ...
# 7328                   4  1542.95400  1545.59800    r      False  ...
#
#      target_angle_90 launch_deviation  launch_dev_z  launch_Speed_z  \
# 0          77.905243       -16.280663      0.156646        3.020865
# 1         102.094757       -20.019617     -0.047681        1.092002
# 2          66.801409         3.371401      1.230595        0.981861
# 3         113.198591       -31.382821     -0.668659        2.808147
# 4         102.094757         1.993943      1.155320        0.985583
# ...              ...              ...           ...             ...
# 7324       77.905243        -1.277063      0.976565        1.754749
# 7325       77.905243        -4.307953      0.810933        2.730645
# 7326      113.198591        -3.803391      0.838506        2.522589
# 7327       66.801409         2.598661      1.188366        1.741533
# 7328      102.094757        -9.582467      0.522690        2.162365
#
#       set_order  sign_label        side target_hit_binary trial_num_target  \
# 0             1         pos    Upstream               0.0                1
# 1             1         neg  Downstream               0.0                1
# 2             1         pos    Upstream               0.0                1
# 3             1         neg  Downstream               0.0                1
# 4             1         neg  Downstream               1.0                2
# ...         ...         ...         ...               ...              ...
# 7324          1         pos    Upstream               1.0               35
# 7325          1         pos    Upstream               0.0               36
# 7326          1         neg  Downstream               0.0              277
# 7327          1         pos    Upstream               1.0               36
# 7328          1         neg  Downstream               0.0               36
#
#      target_x_label
# 0              p0.3
# 1            neg0.3
# 2              p0.6
# 3            neg0.6
# 4            neg0.3
# ...             ...
# 7324           p0.3
# 7325           p0.3
# 7326         neg0.6
# 7327           p0.6
# 7328         neg0.3
#
# [6942 rows x 56 columns]

# %%
###

# %%
# import key libraries and kernel settings
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import json


# updated src file changes are loaded
# %load_ext autoreload
# %autoreload 2

sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd

# load json
df = pd.read_json('../data/solution_space/banana_solutions.json', orient='index')
# turn cols into series
df_tidy = df.stack().apply(pd.Series).reset_index()
df_tidy.columns = ['speed', 'target', 'x_array', 'y_array']
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: target, dtype: bool

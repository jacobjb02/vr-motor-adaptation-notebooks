# %%
# import key libraries and kernel settings
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import json


# updated src file changes are loaded
# %load_ext autoreload
# %autoreload 2

sys.path.append(os.path.abspath(".."))

# %%
df = pd.read_json('../data/solution_space/banana_solutions.json', orient='index')
df['L60']
# Out:
# -2    {'x': [-93.1985905136482, -92.94828300948377, ...
# -3    {'x': [-93.1985905136482, -92.94828300948377, ...
# Name: L60, dtype: object

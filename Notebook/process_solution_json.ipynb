# %%
# import key libraries and kernel settings
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import json


# updated src file changes are loaded
# %load_ext autoreload
# %autoreload 2

sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd

# load json
df = pd.read_json('../data/solution_space/solutions_V2_rel.json', orient='index')
df
# Out:
#                                                   L60  \
# -2  {'x': [-102.9485905136482, -102.6985905136482,...
# -3  {'x': [-100.9485905136482, -100.6985905136482,...
#
#                                                   L30  \
# -2  {'x': [-91.84475707701212, -91.59475707701212,...
# -3  {'x': [-89.59475707701212, -89.34475707701212,...
#
#                                                   R30  \
# -2  {'x': [-67.40524292298791, -67.15524292298791,...
# -3  {'x': [-64.90524292298791, -64.65524292298791,...
#
#                                                   R60
# -2  {'x': [-56.301409486351815, -56.05140948635181...
# -3  {'x': [-53.551409486351815, -53.30140948635181...
